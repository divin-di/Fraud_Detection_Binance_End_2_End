# %%
pip install kafka-python websocket-client
# Out:
# Requirement already satisfied: kafka-python in c:\users\divin\anaconda3\lib\site-packages (2.2.15)
# Requirement already satisfied: websocket-client in c:\users\divin\anaconda3\lib\site-packages (0.58.0)
# Requirement already satisfied: six in c:\users\divin\anaconda3\lib\site-packages (from websocket-client) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json, time, random
import websocket
from kafka import KafkaProducer
from datetime import datetime

# Kafka setup
producer = KafkaProducer(
    bootstrap_servers=['localhost:9092'],  # or EC2 IP
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Binance WebSocket stream for BTC/USDT trades
socket_url = "wss://stream.binance.us:9443/ws/btcusdt@trade"



def on_message(ws, message):
    data = json.loads(message)
    
    # Convert to your transaction schema
    transaction = {
        "txn_id": data["t"],
        "user_id": random.randint(1000, 5000),  # fake user id
        "amount": float(data["p"]) * float(data["q"]),
        "location": random.choice(["US", "UK", "IN", "DE", "SG", "CA"]),
        "merchant_id": hash(data["s"]) % 10000,
        "timestamp": datetime.utcfromtimestamp(data["T"]/1000).isoformat()
    }
    
    # Push to Kafka
    producer.send('transactions', value=transaction)
    print("Produced:", transaction)

def on_error(ws, error):
    print("Error:", error)

def on_close(ws):
    print("WebSocket closed, reconnecting in 5s...")
    time.sleep(5)
    start_stream()

def on_open(ws):
    print("✅ Connected to Binance stream...")

def start_stream():
    ws = websocket.WebSocketApp(
        socket_url,
        on_message=on_message,
        on_error=on_error,
        on_close=on_close
    )
    ws.on_open = on_open
    ws.run_forever()

if __name__ == "__main__":
    start_stream()
# Out:
# ✅ Connected to Binance stream...
# Produced: {'txn_id': 30879727, 'user_id': 4971, 'amount': 1082.0, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:05.091000'}
# Produced: {'txn_id': 30879728, 'user_id': 3940, 'amount': 31.325747800000002, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:10.981000'}
# Produced: {'txn_id': 30879729, 'user_id': 2890, 'amount': 238.72380220000002, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:25.518000'}
# Produced: {'txn_id': 30879730, 'user_id': 4073, 'amount': 51.8495136, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:25.551000'}
# Produced: {'txn_id': 30879731, 'user_id': 2295, 'amount': 130.7039822, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:27.418000'}
# Produced: {'txn_id': 30879732, 'user_id': 1293, 'amount': 879.2813348, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:30.597000'}
# Produced: {'txn_id': 30879733, 'user_id': 4227, 'amount': 1.0801979, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:30.597000'}
# Produced: {'txn_id': 30879734, 'user_id': 4101, 'amount': 49.6891034, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:30.597000'}
# Produced: {'txn_id': 30879735, 'user_id': 3292, 'amount': 15.122769199999999, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:31.682000'}
# Produced: {'txn_id': 30879736, 'user_id': 2913, 'amount': 1.0801978, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:33.295000'}
# Produced: {'txn_id': 30879737, 'user_id': 4231, 'amount': 399.6, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:33.357000'}
# Produced: {'txn_id': 30879738, 'user_id': 4011, 'amount': 402.84, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:52:33.357000'}
# Produced: {'txn_id': 30879739, 'user_id': 3591, 'amount': 3048.84, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879740, 'user_id': 2868, 'amount': 4888.08, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879741, 'user_id': 4582, 'amount': 286.2, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879742, 'user_id': 2511, 'amount': 1999.08, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879743, 'user_id': 3914, 'amount': 498.96, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879744, 'user_id': 1119, 'amount': 100.44000000000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:36.975000'}
# Produced: {'txn_id': 30879745, 'user_id': 3993, 'amount': 2.1598584, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:38.061000'}
# Produced: {'txn_id': 30879746, 'user_id': 3284, 'amount': 17.278608000000002, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:53:38.061000'}
# Produced: {'txn_id': 30879747, 'user_id': 3623, 'amount': 49.7810666, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T03:58:35.361000'}
# Produced: {'txn_id': 30879748, 'user_id': 2009, 'amount': 1.0794966000000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:00:08.152000'}
# Produced: {'txn_id': 30879749, 'user_id': 4022, 'amount': 4.317595600000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:01:28.261000'}
# Produced: {'txn_id': 30879750, 'user_id': 1199, 'amount': 61.509150299999995, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:01:28.261000'}
# Produced: {'txn_id': 30879751, 'user_id': 1760, 'amount': 1524.7523331, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:01:28.261000'}
# Produced: {'txn_id': 30879752, 'user_id': 2351, 'amount': 884.7800000000001, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:01:28.261000'}
# Produced: {'txn_id': 30879753, 'user_id': 3969, 'amount': 15.149367799999998, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:02:50.448000'}
# Produced: {'txn_id': 30879754, 'user_id': 1698, 'amount': 5.410431, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:03:20.446000'}
# Produced: {'txn_id': 30879755, 'user_id': 3112, 'amount': 21.580002, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:03:40.357000'}
# Produced: {'txn_id': 30879756, 'user_id': 1583, 'amount': 161.85, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:04.189000'}
# Produced: {'txn_id': 30879757, 'user_id': 1124, 'amount': 19.4771232, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:05.304000'}
# Produced: {'txn_id': 30879758, 'user_id': 3176, 'amount': 2.1571198000000003, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:09.290000'}
# Produced: {'txn_id': 30879759, 'user_id': 1050, 'amount': 569.3600352, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:16.260000'}
# Produced: {'txn_id': 30879760, 'user_id': 3372, 'amount': 12.9399996, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:16.260000'}
# Produced: {'txn_id': 30879761, 'user_id': 3353, 'amount': 124.00805349999999, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:16.260000'}
# Produced: {'txn_id': 30879762, 'user_id': 1340, 'amount': 958.4322334999999, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:18.354000'}
# Produced: {'txn_id': 30879763, 'user_id': 4509, 'amount': 113.20064699999999, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:18.354000'}
# Produced: {'txn_id': 30879764, 'user_id': 3062, 'amount': 328.73815, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:20.920000'}
# Produced: {'txn_id': 30879765, 'user_id': 4382, 'amount': 25.867917600000002, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:21.919000'}
# Produced: {'txn_id': 30879766, 'user_id': 1143, 'amount': 3.2329527, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:22.932000'}
# Produced: {'txn_id': 30879767, 'user_id': 3158, 'amount': 4.310569600000001, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:22.932000'}
# Produced: {'txn_id': 30879768, 'user_id': 1851, 'amount': 430.89092, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:23.940000'}
# Produced: {'txn_id': 30879769, 'user_id': 4208, 'amount': 9.723122100000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:32.964000'}
# Produced: {'txn_id': 30879770, 'user_id': 1970, 'amount': 64.63363199999999, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:46.151000'}
# Produced: {'txn_id': 30879771, 'user_id': 1709, 'amount': 56.0158092, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:46.151000'}
# Produced: {'txn_id': 30879772, 'user_id': 1367, 'amount': 2.1540280000000003, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:46.662000'}
# Produced: {'txn_id': 30879773, 'user_id': 3394, 'amount': 25.841472000000003, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:48.107000'}
# Produced: {'txn_id': 30879774, 'user_id': 2689, 'amount': 6.4603206, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:49.175000'}
# Produced: {'txn_id': 30879775, 'user_id': 3252, 'amount': 1.0767201, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:50.182000'}
# Produced: {'txn_id': 30879776, 'user_id': 3870, 'amount': 2.1605278, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:50.503000'}
# Produced: {'txn_id': 30879777, 'user_id': 1354, 'amount': 4.306401200000001, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:04:53.147000'}
# Produced: {'txn_id': 30879778, 'user_id': 2232, 'amount': 192.6905286, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:05:06.557000'}
# Produced: {'txn_id': 30879779, 'user_id': 3404, 'amount': 12.917484, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:05:06.557000'}
# Produced: {'txn_id': 30879780, 'user_id': 1871, 'amount': 490.7735112, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:05:07.775000'}
# Produced: {'txn_id': 30879781, 'user_id': 4400, 'amount': 2.15831, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:23.781000'}
# Produced: {'txn_id': 30879782, 'user_id': 4335, 'amount': 10.78655, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:36.418000'}
# Produced: {'txn_id': 30879783, 'user_id': 3765, 'amount': 10.781550000000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:50.195000'}
# Produced: {'txn_id': 30879784, 'user_id': 3552, 'amount': 32.283311999999995, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:52.150000'}
# Produced: {'txn_id': 30879785, 'user_id': 1803, 'amount': 1.0761104000000001, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:52.194000'}
# Produced: {'txn_id': 30879786, 'user_id': 3127, 'amount': 11.8335767, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879787, 'user_id': 4065, 'amount': 10.757577000000001, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879788, 'user_id': 4219, 'amount': 10.757577000000001, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879789, 'user_id': 4851, 'amount': 10.757577000000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879790, 'user_id': 1945, 'amount': 10.757577000000001, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879791, 'user_id': 3388, 'amount': 10.757577000000001, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:55.413000'}
# Produced: {'txn_id': 30879792, 'user_id': 1959, 'amount': 47.3286924, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.629000'}
# Produced: {'txn_id': 30879793, 'user_id': 1695, 'amount': 1.0756521, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.760000'}
# Produced: {'txn_id': 30879794, 'user_id': 1559, 'amount': 5.378198, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.760000'}
# Produced: {'txn_id': 30879795, 'user_id': 2540, 'amount': 95.7214224, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.760000'}
# Produced: {'txn_id': 30879796, 'user_id': 2057, 'amount': 22.579000500000003, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.760000'}
# Produced: {'txn_id': 30879797, 'user_id': 1974, 'amount': 387.06624, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:56.760000'}
# Produced: {'txn_id': 30879798, 'user_id': 3079, 'amount': 450.5021798, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:06:58.646000'}
# Produced: {'txn_id': 30879799, 'user_id': 1733, 'amount': 226.8638662, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:05.666000'}
# Produced: {'txn_id': 30879800, 'user_id': 4704, 'amount': 32.255523, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:05.666000'}
# Produced: {'txn_id': 30879801, 'user_id': 3527, 'amount': 142.999472, 'location': 'SG', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:05.666000'}
# Produced: {'txn_id': 30879802, 'user_id': 2548, 'amount': 5.3784185, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:35.333000'}
# Produced: {'txn_id': 30879803, 'user_id': 2308, 'amount': 1488.7462408, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:39.675000'}
# Produced: {'txn_id': 30879804, 'user_id': 2370, 'amount': 10.75684, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:39.675000'}
# Produced: {'txn_id': 30879805, 'user_id': 4572, 'amount': 10.75684, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:39.675000'}
# Produced: {'txn_id': 30879806, 'user_id': 1049, 'amount': 10.756842, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:40.683000'}
# Produced: {'txn_id': 30879807, 'user_id': 1773, 'amount': 9.685656, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:07:50.361000'}
# Produced: {'txn_id': 30879808, 'user_id': 2051, 'amount': 10.761842, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:08:07.759000'}
# Produced: {'txn_id': 30879809, 'user_id': 3996, 'amount': 1792.6786935000002, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:08:38.490000'}
# Produced: {'txn_id': 30879810, 'user_id': 2697, 'amount': 10.76684, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:08:39.497000'}
# Produced: {'txn_id': 30879811, 'user_id': 1931, 'amount': 1684.5675088, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:08:45.824000'}
# Produced: {'txn_id': 30879812, 'user_id': 3438, 'amount': 39.9001562, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:10:16.940000'}
# Produced: {'txn_id': 30879813, 'user_id': 2796, 'amount': 19.3787586, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:10:53.858000'}
# Produced: {'txn_id': 30879814, 'user_id': 1007, 'amount': 32.297934, 'location': 'UK', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:10:56.601000'}
# Error:
# WebSocket closed, reconnecting in 5s...
# ✅ Connected to Binance stream...
# Produced: {'txn_id': 30879815, 'user_id': 3168, 'amount': 24.8200245, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:12:05.459000'}
# Produced: {'txn_id': 30879816, 'user_id': 1557, 'amount': 8.6127144, 'location': 'IN', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:12:12.675000'}
# Produced: {'txn_id': 30879817, 'user_id': 3275, 'amount': 5.395607, 'location': 'US', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:12:28.161000'}
# Produced: {'txn_id': 30879818, 'user_id': 3630, 'amount': 9.7118055, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:13:35.406000'}
# Produced: {'txn_id': 30879819, 'user_id': 4058, 'amount': 17.265120000000003, 'location': 'DE', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:14:19.609000'}
# Error:
# WebSocket closed, reconnecting in 5s...
# ✅ Connected to Binance stream...
# Produced: {'txn_id': 30879820, 'user_id': 1489, 'amount': 10.765892000000001, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:15:24.350000'}
# Produced: {'txn_id': 30879821, 'user_id': 2996, 'amount': 10.765892000000001, 'location': 'CA', 'merchant_id': 5810, 'timestamp': '2025-11-03T04:15:24.350000'}
